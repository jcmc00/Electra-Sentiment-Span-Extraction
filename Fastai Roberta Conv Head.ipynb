# %%
import transformers
from transformers import AutoModelForQuestionAnswering, AutoModel, AutoConfig, get_linear_schedule_with_warmup
from transformers.optimization import AdamW
import torch
import torch.nn as nn
import torch.nn.functional as F
import pytorch_lightning as pl
import pandas as pd
import numpy as np
from pathlib import Path
import os
from itertools import compress
import utils
from sklearn.model_selection import StratifiedKFold

# %%
from torch.utils.data import DataLoader
from apex.optimizers.fused_lamb import FusedLAMB as Lamb
from ranger import Ranger
from fairseq import criterions 
from functools import partial
from tokenizers import BertWordPieceTokenizer
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from fastai.core import *
from fastai.text import *

# %%
path = Path.cwd()
file_dir = Path.cwd()/'data'

# %%
train_df = pd.read_csv(file_dir/'train.csv')
train_df['text'] = train_df['text'].apply(lambda x: str(x))
train_df['sentiment'] = train_df['sentiment'].apply(lambda x: str(x))
train_df['selected_text'] = train_df['selected_text'].apply(lambda x: str(x))

# %%
test_df = pd.read_csv(file_dir/'test.csv')
test_df['text'] = test_df['text'].apply(lambda x: str(x))
test_df['sentiment'] = test_df['sentiment'].apply(lambda x: str(x))

# %%
max_len = 128
bs = 32
tokenizer = transformers.RobertaTokenizerFast('input/roberta-base/vocab.json', 'input/roberta-base/merges.txt',
                                  lowercase=True,add_prefix_space=True).tokenizer
# Out:
# WARNING:transformers.tokenization_roberta:RobertaTokenizerFast has an issue when working on mask language modeling where it introduces an extra encoded space before the mask token.See https://github.com/huggingface/transformers/pull/2778 for more information.

# %%
def preprocess(sentiment, tweet, selected, tokenizer, max_len):
    _input = tokenizer.encode(sentiment, tweet)
    _span = tokenizer.encode(selected, add_special_tokens=False)
    
    len_span = len(_span.ids)
    start_idx = None
    end_idx = None
    
    for ind in (i for i, e in enumerate(_input.ids) if e == _span.ids[0]):
        if _input.ids[ind: ind + len_span] == _span.ids:
            start_idx = ind
            end_idx = ind + len_span - 1
            break
    
    # Handles cases where tokenizing input & span separately produces different outputs
    if not start_idx:
        idx0 = tweet.find(selected)
        idx1 = idx0 + len(selected)
        
        char_targets = [0] * len(tweet)
        if idx0 != None and idx1 != None:
            for ct in range(idx0, idx1):
                char_targets[ct] = 1
                
        tweet_offsets = _input.offsets[4:-1]
        
        target_idx = []
        for j, (offset1, offset2) in enumerate(tweet_offsets):
            if sum(char_targets[offset1: offset2]) > 0:
                target_idx.append(j)
                
        start_idx, end_idx = target_idx[0] + 4 , target_idx[-1] + 4
        
    _input.start_target = start_idx
    _input.end_target = end_idx
    _input.tweet = tweet
    _input.sentiment = sentiment
    _input.selected = selected
    
    _input.pad(max_len)
    
    return _input

# %%
def reduce_loss(loss, reduction='mean'):
    return loss.mean() if reduction=='mean' else loss.sum() if reduction=='sum' else loss    

class LabelSmoothingCrossEntropy(nn.Module):
    def __init__(self, ε:float=0.1, reduction='mean'):
        super().__init__()
        self.ε,self.reduction = ε,reduction
    
    def forward(self, output, target):
        c = output.size()[-1]
        log_preds = F.log_softmax(output, dim=-1)
        loss = reduce_loss(-log_preds.sum(dim=-1), self.reduction)
        nll = F.nll_loss(log_preds, target, reduction=self.reduction)
        return torch.lerp(nll, loss/c, self.ε)

# %%
class TweetDataset(Dataset):
    def __init__(self, dataset, test = None):
        self.df = dataset
        self.test = test
        
    def __getitem__(self, idx):
        if not self.test:
            sentiment, tweet, selected = (self.df[col][idx] for col in ['sentiment', 'text', 'selected_text'])
            _input = preprocess(sentiment, tweet, selected, tokenizer, max_len)
            
            yb = [torch.tensor(_input.start_target), torch.tensor(_input.end_target)]
            
        else:
            _input = tokenizer.encode(self.df.sentiment[idx], self.df.text[idx])
            _input.pad(max_len)
            
            yb = 0

        xb = [torch.LongTensor(_input.ids),
              torch.LongTensor(_input.attention_mask),
              np.array(_input.offsets)]

        return xb, yb     

    def __len__(self):
        return len(self.df)

# %%
roberta_path = 'input/roberta-base'
pt_model = AutoModel.from_pretrained(roberta_path)
# Out:
# INFO:transformers.configuration_utils:loading configuration file input/roberta-base/config.json
# INFO:transformers.configuration_utils:Model config RobertaConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "RobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": 0,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": 2,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-05,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 514,
#   "min_length": 0,
#   "model_type": "roberta",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": true,
#   "output_past": true,
#   "pad_token_id": 1,
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 1,
#   "use_bfloat16": false,
#   "vocab_size": 50265
# }
#
# INFO:transformers.modeling_utils:loading weights file input/roberta-base/pytorch_model.bin

# %%
class Mish(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x): 
        
        x = x * (torch.tanh(F.softplus(x)))

        return x

# %%
class SpanModel(nn.Module):
    def __init__(self,pt_model):
        super().__init__()
        self.model = pt_model
        self.drop_out = nn.Dropout(0.1)
        self.qa_outputs1c = torch.nn.Conv1d(768*2, 128, 2)
        self.qa_outputs2c = torch.nn.Conv1d(768*2, 128, 2)
        self.qa_outputs1 = nn.Linear(128, 1)
        self.qa_outputs2 = nn.Linear(128, 1)
        
#         self.qa_outputs = nn.Linear(768 * 2, 2) # update hidden size

    # could pass offsets here and not use - can grab in last_input
    def forward(self, input_ids, attention_mask, offsets = None):
        
        _, _, hidden_states = self.model(input_ids, attention_mask=attention_mask)

        out = torch.cat((hidden_states[-1], hidden_states[-2]), dim=-1)
        out = self.drop_out(out)
        out = torch.nn.functional.pad(out.transpose(1,2), (1, 0))
        
        out1 = self.qa_outputs1c(out).transpose(1,2)
        out2 = self.qa_outputs2c(out).transpose(1,2)

        start_logits = self.qa_outputs1(self.drop_out(out1)).squeeze(-1)
        end_logits = self.qa_outputs2(self.drop_out(out2)).squeeze(-1)
        return start_logits, end_logits

# %%
class SpanModel2(nn.Module):
    def __init__(self,pt_model):
        super().__init__()
        self.model = pt_model
        self.drop_out = nn.Dropout(0.2)
        self.qa_outputs1c = torch.nn.Conv1d(768*2, 128, 2)
        self.qa_outputs2c = torch.nn.Conv1d(768*2, 128, 2)
#         self.LRelu = torch.nn.LeakyReLU()
        self.mish = Mish()
        self.qa_outputs1 = nn.Linear(128, 1)
        self.qa_outputs2 = nn.Linear(128, 1)
        
#         self.qa_outputs = nn.Linear(768 * 2, 2) # update hidden size

    # could pass offsets here and not use - can grab in last_input
    def forward(self, input_ids, attention_mask, offsets = None):
        
        _, _, hidden_states = self.model(input_ids, attention_mask=attention_mask)

        out = torch.cat((hidden_states[-1], hidden_states[-2]), dim=-1)
        out = self.drop_out(out)
        out = torch.nn.functional.pad(out.transpose(1,2), (1, 0))
        
        out1 = self.qa_outputs1c(out).transpose(1,2)
        out1 = self.mish(out1)
        
        out2 = self.qa_outputs2c(out).transpose(1,2)
        out2 = self.mish(out2)

        start_logits = self.qa_outputs1(self.drop_out(out1)).squeeze(-1)
        end_logits = self.qa_outputs2(self.drop_out(out2)).squeeze(-1)
        return start_logits, end_logits

# %%
def dist_between(start_logits, end_logits, device='cpu', max_seq_len=128):
    """get dist btw. pred & ground_truth"""

    linear_func = torch.tensor(np.linspace(0, 1, max_seq_len, endpoint=False), requires_grad=False)
    linear_func = linear_func.to(device)

    start_pos = (start_logits*linear_func).sum(axis=1)
    end_pos = (end_logits*linear_func).sum(axis=1)

    diff = end_pos-start_pos

    return diff.sum(axis=0)/diff.size(0)


def dist_loss(start_logits, end_logits, start_positions, end_positions, device='cpu', max_seq_len=128, scale=1):
    """calculate distance loss between prediction's length & GT's length
    
    Input
    - start_logits ; shape (batch, max_seq_len{128})
        - logits for start index
    - end_logits
        - logits for end index
    - start_positions ; shape (batch, 1)
        - start index for GT
    - end_positions
        - end index for GT
    """
    start_logits = torch.nn.Softmax(1)(start_logits) # shape ; (batch, max_seq_len)
    end_logits = torch.nn.Softmax(1)(end_logits)
    
    start_one_hot = torch.nn.functional.one_hot(start_positions, num_classes=max_seq_len).to(device)
    end_one_hot = torch.nn.functional.one_hot(end_positions, num_classes=max_seq_len).to(device)
    
    pred_dist = dist_between(start_logits, end_logits, device, max_seq_len)
    gt_dist = dist_between(start_one_hot, end_one_hot, device, max_seq_len) # always positive
    diff = (gt_dist-pred_dist)

    rev_diff_squared = 1-torch.sqrt(diff*diff) # as diff is smaller, make it get closer to the one
    loss = -torch.log(rev_diff_squared) # by using negative log function, if argument is near zero -> inifinite, near one -> zero

    return loss*scale

# %%
class JaccardExpectationLoss(nn.Module):
    def __init__(self):
        super(JaccardExpectationLoss, self).__init__()
        self.softmax = nn.Softmax(dim=-1)
        self.relu = nn.ReLU()

    def forward(self, start_logits, end_logits, start_positions, end_positions):
        indexes = torch.arange(start_logits.size()[1]).unsqueeze(0).cuda()

        start_pred = torch.sum(self.softmax(start_logits) * indexes, dim=1)
        end_pred = torch.sum(self.softmax(end_logits) * indexes, dim=1)

        len_true = end_positions - start_positions + 1
        intersection = len_true - self.relu(start_pred - start_positions) - self.relu(end_positions - end_pred)
        union = len_true + self.relu(start_positions - start_pred) + self.relu(end_pred - end_positions)

        jel = 1 - intersection / union
        jel = torch.mean(jel)
        return jel

# %%
class join_loss(Module):
    def __init__(self, ce_loss_fn = nn.CrossEntropyLoss(), device = 'cpu'): 
        self.loss_fn = ce_loss_fn
        self.device = device
        
    def forward(self, inputs, start_targets, end_targets):
        start_logits, end_logits = inputs # assumes tuple input
        
        logits = torch.cat([start_logits, end_logits]).contiguous()
        
        targets = torch.cat([start_targets, end_targets]).contiguous()
        
        ce_loss = self.loss_fn(logits, targets)
        
        distance_loss = dist_loss(start_logits, end_logits, 
                                  start_targets, end_targets, device=device, max_seq_len =128)
        return ce_loss+distance_loss

# %%
class join_loss2(Module):
    def __init__(self, ce_loss_fn = nn.CrossEntropyLoss()): 
        self.loss_fn = ce_loss_fn
        self.jel = JaccardExpectationLoss()
        
    def forward(self, inputs, start_targets, end_targets):
        start_logits, end_logits = inputs # assumes tuple input
        
        logits = torch.cat([start_logits, end_logits]).contiguous()
        
        targets = torch.cat([start_targets, end_targets]).contiguous()
        
        ce_loss = self.loss_fn(logits, targets)
        
        jel_loss = self.jel(start_logits, end_logits, 
                                  start_targets, end_targets)
        
        return ce_loss+jel_loss

# %%
class CELoss(Module):
    def __init__(self, loss_fn = nn.CrossEntropyLoss()): 
        self.loss_fn = loss_fn
        
    def forward(self, inputs, start_targets, end_targets):
        start_logits, end_logits = inputs # assumes tuple input
        
        logits = torch.cat([start_logits, end_logits]).contiguous()
        
        targets = torch.cat([start_targets, end_targets]).contiguous()
        
        return self.loss_fn(logits, targets)

# %%
def jaccard(str1, str2): 
    a = set(str1.lower().split()) 
    b = set(str2.lower().split())
    c = a.intersection(b)
    return float(len(c)) / (len(a) + len(b) - len(c))

# %%
def get_best_start_end_idxs(start_logits, end_logits):
    max_len = len(start_logits)
    start_logits, end_logits = start_logits.cpu(),end_logits.cpu()
    
    a = np.tile(start_logits, (max_len, 1))
    b = np.tile(end_logits, (max_len, 1))
    c = np.tril(a + b.T, k=0).T
    c[c == 0] = -1000
    return np.unravel_index(c.argmax(), c.shape)

# %%
# Note that validation ds is by default not shuffled in fastai - so indexing like this will work for Callback
# https://forums.fast.ai/t/how-to-set-shuffle-false-of-train-and-val/33730

class JaccardScore(Callback):
    "Stores predictions and targets to perform calculations on epoch end."
    def __init__(self, valid_ds): 
        self.valid_ds = valid_ds
        self.context_text = valid_ds.df.text
        self.answer_text = valid_ds.df.selected_text
        
    def on_epoch_begin(self, **kwargs):
        self.jaccard_scores = []  
        self.valid_ds_idx = 0
        
        
    def on_batch_end(self, last_input:Tensor, last_output:Tensor, last_target:Tensor, **kwargs):
              
        input_ids = last_input[0]
        offsets = last_input[2]

        start_logits, end_logits = last_output
        
        # for id in batch of ids
        for i in range(len(input_ids)):
            
            _offsets = offsets[i]
#             start_idx, end_idx = torch.argmax(start_logits[i]), torch.argmax(end_logits[i])
            
            start_idx, end_idx = get_best_start_end_idxs(start_logits[i], end_logits[i])
            
            _answer_text = self.answer_text[self.valid_ds_idx]
            original_start, original_end = _offsets[start_idx][0], _offsets[end_idx][1]
            pred_span = self.context_text[self.valid_ds_idx][original_start : original_end]
                
            score = jaccard(pred_span, _answer_text)
            self.jaccard_scores.append(score)

            self.valid_ds_idx += 1
            
    def on_epoch_end(self, last_metrics, **kwargs):        
        res = np.mean(self.jaccard_scores)
        return add_metrics(last_metrics, res)

# %%
from fastai.callbacks import *

def new_on_train_begin(self, **kwargs:Any)->None:
    "Initializes the best value."
    if not hasattr(self, 'best'):
        self.best = float('inf') if self.operator == np.less else -float('inf')

SaveModelCallback.on_train_begin = new_on_train_begin

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
fold_indices = list(skf.split(train_df, train_df.sentiment))

# %%
device = torch.device('cuda')

def run_fold(fold):
    wd = 0.01 # high value but worked quite well
    lr = 1e-4
    
    tr_df  = train_df.iloc[fold_indices[fold][0]].reset_index(drop=True)
    val_df = train_df.iloc[fold_indices[fold][1]].reset_index(drop=True)
    
    train_ds, valid_ds = [TweetDataset(i) for i in [tr_df,val_df]]
    data = DataBunch.create(train_ds, valid_ds,bs = bs)
#     loss_fn = partial(CELoss, LabelSmoothingCrossEntropy())
#     loss_fn = join_loss(LabelSmoothingCrossEntropy(), device) # no need to initialise later - no partial 
    loss_fn = join_loss2(LabelSmoothingCrossEntropy())

    pt_model = AutoModel.from_pretrained(roberta_path)
    model = SpanModel(pt_model)
    learner = Learner(data, model, loss_func = loss_fn, opt_func = Ranger, metrics = [JaccardScore(valid_ds)])
    
    early_stop_cb = EarlyStoppingCallback(learner, monitor='jaccard_score',mode='max',patience=2)
    save_model_cb = SaveModelCallback(learner,every='improvement',monitor='jaccard_score',name=f'roberta_conv_news_fold_{fold}')
    csv_logger_cb = CSVLogger(learner, f"roberta_conv_logs_{fold}", True)

    learner.fit_fc(11, 3e-5 ,start_pct=0.7, wd=wd, callbacks=[early_stop_cb, save_model_cb, csv_logger_cb])
    
#     learner.fit_fc(3e-5, lr ,start_pct=0.7, wd=wd, callbacks=[early_stop_cb, save_model_cb, csv_logger_cb])

    learner.save(f'roberta_conv_news_after_epoch_{fold}', with_opt=False)
    del learner; del pt_model; gc.collect()

# %%
for fold in range(5):run_fold(fold)
# Out:
# INFO:transformers.configuration_utils:loading configuration file input/roberta-base/config.json
# INFO:transformers.configuration_utils:Model config RobertaConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "RobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": 0,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": 2,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-05,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 514,
#   "min_length": 0,
#   "model_type": "roberta",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": true,
#   "output_past": true,
#   "pad_token_id": 1,
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 1,
#   "use_bfloat16": false,
#   "vocab_size": 50265
# }
#
# INFO:transformers.modeling_utils:loading weights file input/roberta-base/pytorch_model.bin
# Ranger optimizer loaded.
# Gradient Centralization usage = True
# GC applied to both conv and fc layers
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='11' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       54.55% [6/11 56:51<47:22]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>jaccard_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.202166</td>
#       <td>2.171898</td>
#       <td>0.688536</td>
#       <td>09:39</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.070406</td>
#       <td>2.099770</td>
#       <td>0.698596</td>
#       <td>09:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.975594</td>
#       <td>2.051471</td>
#       <td>0.700281</td>
#       <td>09:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.912520</td>
#       <td>2.031664</td>
#       <td>0.707751</td>
#       <td>09:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.893500</td>
#       <td>2.041682</td>
#       <td>0.706538</td>
#       <td>09:22</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.827562</td>
#       <td>2.064327</td>
#       <td>0.705566</td>
#       <td>09:22</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='172' class='' max='172' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [172/172 00:43<00:00]
#     </div>
# Better model found at epoch 0 with jaccard_score value: 0.6885358314943907.
# Better model found at epoch 1 with jaccard_score value: 0.6985955435016602.
# Better model found at epoch 2 with jaccard_score value: 0.7002808767335673.
# Better model found at epoch 3 with jaccard_score value: 0.7077513993832506.
# Epoch 6: early stopping
# set state called
# INFO:transformers.configuration_utils:loading configuration file input/roberta-base/config.json
# INFO:transformers.configuration_utils:Model config RobertaConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "RobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": 0,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": 2,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-05,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 514,
#   "min_length": 0,
#   "model_type": "roberta",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": true,
#   "output_past": true,
#   "pad_token_id": 1,
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 1,
#   "use_bfloat16": false,
#   "vocab_size": 50265
# }
#
# INFO:transformers.modeling_utils:loading weights file input/roberta-base/pytorch_model.bin
# Ranger optimizer loaded.
# Gradient Centralization usage = True
# GC applied to both conv and fc layers
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='11' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       45.45% [5/11 47:04<56:29]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>jaccard_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.265704</td>
#       <td>2.160805</td>
#       <td>0.687839</td>
#       <td>09:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.105697</td>
#       <td>2.066097</td>
#       <td>0.707562</td>
#       <td>09:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.993706</td>
#       <td>2.031105</td>
#       <td>0.712601</td>
#       <td>09:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.976372</td>
#       <td>2.015620</td>
#       <td>0.707488</td>
#       <td>09:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.890057</td>
#       <td>2.005164</td>
#       <td>0.704842</td>
#       <td>09:23</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='172' class='' max='172' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [172/172 00:43<00:00]
#     </div>
# Better model found at epoch 0 with jaccard_score value: 0.6878394403681182.
# Better model found at epoch 1 with jaccard_score value: 0.7075615959772799.
# Better model found at epoch 2 with jaccard_score value: 0.7126013431541354.
# Epoch 5: early stopping
# set state called
# INFO:transformers.configuration_utils:loading configuration file input/roberta-base/config.json
# INFO:transformers.configuration_utils:Model config RobertaConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "RobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": 0,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": 2,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-05,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 514,
#   "min_length": 0,
#   "model_type": "roberta",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": true,
#   "output_past": true,
#   "pad_token_id": 1,
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 1,
#   "use_bfloat16": false,
#   "vocab_size": 50265
# }
#
# INFO:transformers.modeling_utils:loading weights file input/roberta-base/pytorch_model.bin
# Ranger optimizer loaded.
# Gradient Centralization usage = True
# GC applied to both conv and fc layers
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='11' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       54.55% [6/11 56:27<47:02]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>jaccard_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.285354</td>
#       <td>2.190450</td>
#       <td>0.677029</td>
#       <td>09:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.086771</td>
#       <td>2.075686</td>
#       <td>0.707338</td>
#       <td>09:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.021292</td>
#       <td>2.032639</td>
#       <td>0.702290</td>
#       <td>09:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.979964</td>
#       <td>2.010003</td>
#       <td>0.711948</td>
#       <td>09:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.902113</td>
#       <td>2.014407</td>
#       <td>0.710595</td>
#       <td>09:22</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.828384</td>
#       <td>2.042181</td>
#       <td>0.710657</td>
#       <td>09:22</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='172' class='' max='172' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [172/172 00:43<00:00]
#     </div>
# Better model found at epoch 0 with jaccard_score value: 0.6770294334617466.
# Better model found at epoch 1 with jaccard_score value: 0.7073380955228691.
# Better model found at epoch 3 with jaccard_score value: 0.7119476687892761.
# Epoch 6: early stopping
# set state called
# INFO:transformers.configuration_utils:loading configuration file input/roberta-base/config.json
# INFO:transformers.configuration_utils:Model config RobertaConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "RobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": 0,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": 2,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-05,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 514,
#   "min_length": 0,
#   "model_type": "roberta",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": true,
#   "output_past": true,
#   "pad_token_id": 1,
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 1,
#   "use_bfloat16": false,
#   "vocab_size": 50265
# }
#
# INFO:transformers.modeling_utils:loading weights file input/roberta-base/pytorch_model.bin
# Ranger optimizer loaded.
# Gradient Centralization usage = True
# GC applied to both conv and fc layers
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9' class='' max='11' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       81.82% [9/11 1:24:39<18:48]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>jaccard_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.246220</td>
#       <td>2.184458</td>
#       <td>0.686684</td>
#       <td>09:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.114060</td>
#       <td>2.036966</td>
#       <td>0.705485</td>
#       <td>09:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.006424</td>
#       <td>2.006168</td>
#       <td>0.708894</td>
#       <td>09:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.971405</td>
#       <td>1.996889</td>
#       <td>0.704794</td>
#       <td>09:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.877421</td>
#       <td>2.018794</td>
#       <td>0.708881</td>
#       <td>09:23</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.818184</td>
#       <td>2.026209</td>
#       <td>0.709678</td>
#       <td>09:23</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.761049</td>
#       <td>2.051793</td>
#       <td>0.711111</td>
#       <td>09:23</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.683529</td>
#       <td>2.106042</td>
#       <td>0.707885</td>
#       <td>09:23</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.583682</td>
#       <td>2.146745</td>
#       <td>0.708583</td>
#       <td>09:23</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='172' class='' max='172' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [172/172 00:43<00:00]
#     </div>
# Better model found at epoch 0 with jaccard_score value: 0.686683764047098.
# Better model found at epoch 1 with jaccard_score value: 0.7054851424877298.
# Better model found at epoch 2 with jaccard_score value: 0.7088940068433014.
# Better model found at epoch 5 with jaccard_score value: 0.709678282284258.
# Better model found at epoch 6 with jaccard_score value: 0.7111111413678048.
# Epoch 9: early stopping
# set state called
# INFO:transformers.configuration_utils:loading configuration file input/roberta-base/config.json
# INFO:transformers.configuration_utils:Model config RobertaConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "RobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": 0,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": 2,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-05,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 514,
#   "min_length": 0,
#   "model_type": "roberta",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": true,
#   "output_past": true,
#   "pad_token_id": 1,
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 1,
#   "use_bfloat16": false,
#   "vocab_size": 50265
# }
#
# INFO:transformers.modeling_utils:loading weights file input/roberta-base/pytorch_model.bin
# Ranger optimizer loaded.
# Gradient Centralization usage = True
# GC applied to both conv and fc layers
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='11' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       54.55% [6/11 56:27<47:02]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>jaccard_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.199582</td>
#       <td>2.172006</td>
#       <td>0.693114</td>
#       <td>09:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.070554</td>
#       <td>2.075593</td>
#       <td>0.697418</td>
#       <td>09:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.966836</td>
#       <td>2.036586</td>
#       <td>0.704000</td>
#       <td>09:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.946774</td>
#       <td>2.002420</td>
#       <td>0.708841</td>
#       <td>09:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.883796</td>
#       <td>2.037194</td>
#       <td>0.706539</td>
#       <td>09:22</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.793461</td>
#       <td>2.049458</td>
#       <td>0.707556</td>
#       <td>09:22</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='172' class='' max='172' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [172/172 00:43<00:00]
#     </div>
# Better model found at epoch 0 with jaccard_score value: 0.693114449345234.
# Better model found at epoch 1 with jaccard_score value: 0.6974181455814191.
# Better model found at epoch 2 with jaccard_score value: 0.7040000105703113.
# Better model found at epoch 3 with jaccard_score value: 0.708840808277601.
# Epoch 6: early stopping
# set state called

# %% [markdown]
# ### Predict

# %%
pt_model = AutoModel.from_pretrained(roberta_path)
model = SpanModel(pt_model)

tr_df  = train_df.iloc[fold_indices[0][0]].reset_index(drop=True)
val_df = train_df.iloc[fold_indices[0][1]].reset_index(drop=True)

train_ds, valid_ds = [TweetDataset(i) for i in [tr_df, val_df]]
test_ds = TweetDataset(test_df, test = True)
loss_fn = partial(CELoss, LabelSmoothingCrossEntropy())

data = DataBunch.create(train_ds, valid_ds, test_ds, path=".", bs = 128)
# learner = Learner(data, model, loss_func = loss_fn(), path = path/'models/electra/models', model_dir=f".")
learner = Learner(data, model, loss_func = loss_fn(), path = path/'models/roberta_ranger_new_loss_fc', model_dir=f".")
# Out:
# INFO:transformers.configuration_utils:loading configuration file input/roberta-base/config.json
# INFO:transformers.configuration_utils:Model config RobertaConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "RobertaModel"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": 0,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": 2,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "is_decoder": false,
#   "is_encoder_decoder": false,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1
#   },
#   "layer_norm_eps": 1e-05,
#   "length_penalty": 1.0,
#   "max_length": 20,
#   "max_position_embeddings": 514,
#   "min_length": 0,
#   "model_type": "roberta",
#   "no_repeat_ngram_size": 0,
#   "num_attention_heads": 12,
#   "num_beams": 1,
#   "num_hidden_layers": 12,
#   "num_return_sequences": 1,
#   "output_attentions": false,
#   "output_hidden_states": true,
#   "output_past": true,
#   "pad_token_id": 1,
#   "prefix": null,
#   "pruned_heads": {},
#   "repetition_penalty": 1.0,
#   "task_specific_params": null,
#   "temperature": 1.0,
#   "top_k": 50,
#   "top_p": 1.0,
#   "torchscript": false,
#   "type_vocab_size": 1,
#   "use_bfloat16": false,
#   "vocab_size": 50265
# }
#
# INFO:transformers.modeling_utils:loading weights file input/roberta-base/pytorch_model.bin

# %%
learner2 = Learner(data, model, loss_func = loss_fn(), path = path/'models/jel_loss', model_dir=f".")

# %%
model2 = SpanModel2(pt_model)
learner3 =  Learner(data, model, loss_func = loss_fn(), path = path/'models/roberta_mish', model_dir=f".")

# %%
a = iter(learner.data.train_dl)

# %%
model0()
# Out:
# SpanModel(
#   (model): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (drop_out): Dropout(p=0.2, inplace=False)
#   (qa_outputs1c): Conv1d(1536, 128, kernel_size=(2,), stride=(1,))
#   (qa_outputs2c): Conv1d(1536, 128, kernel_size=(2,), stride=(1,))
#   (mish): Mish()
#   (qa_outputs1): Linear(in_features=128, out_features=1, bias=True)
#   (qa_outputs2): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
preds = []
test_df_idx = 0

with torch.no_grad():
    
    for xb,yb in tqdm(learner.data.test_dl):
        model0 = learner.load(f'roberta_conv_update_N_0').model.eval()
        start_logits0, end_logits0 = to_cpu(model0(*xb))
        start_logits0, end_logits0 = start_logits0.float(), end_logits0.float()
        
        model1 = learner.load(f'roberta_conv_update_N_1').model.eval()
        start_logits1, end_logits1 = to_cpu(model1(*xb))
        start_logits1, end_logits1 = start_logits1.float(), end_logits1.float()
        
        model2 = learner.load(f'roberta_conv_update_N_2').model.eval()
        start_logits2, end_logits2 = to_cpu(model2(*xb))
        start_logits2, end_logits2 = start_logits2.float(), end_logits2.float()
        
        model3 = learner.load(f'roberta_conv_update_N_3').model.eval()
        start_logits3, end_logits3 = to_cpu(model3(*xb))
        start_logits3, end_logits3 = start_logits3.float(), end_logits3.float()
        
        model4 = learner.load(f'roberta_conv_update_N_4').model.eval()
        start_logits4, end_logits4 = to_cpu(model4(*xb))
        start_logits4, end_logits4 = start_logits4.float(), end_logits4.float()
        
        #######################################################################
        
        model5 = learner2.load(f'roberta_conv_jel_loss_0').model.eval()
        start_logits5, end_logits5 = to_cpu(model5(*xb))
        start_logits5, end_logits5 = start_logits5.float(), end_logits5.float()
        
        model6 = learner2.load(f'roberta_conv_jel_loss_1').model.eval()
        start_logits6, end_logits6 = to_cpu(model6(*xb))
        start_logits6, end_logits6 = start_logits6.float(), end_logits6.float()
        
        model7 = learner2.load(f'roberta_conv_jel_loss_2').model.eval()
        start_logits7, end_logits7 = to_cpu(model7(*xb))
        start_logits7, end_logits7 = start_logits7.float(), end_logits7.float()
        
        model8 = learner2.load(f'roberta_conv_jel_loss_3').model.eval()
        start_logits8, end_logits8 = to_cpu(model8(*xb))
        start_logits8, end_logits8 = start_logits8.float(), end_logits8.float()
        
        model9 = learner2.load(f'roberta_conv_jel_loss_4').model.eval()
        start_logits9, end_logits9 = to_cpu(model9(*xb))
        start_logits9, end_logits9 = start_logits9.float(), end_logits9.float()
        
        #######################################################################
        
        model10 = learner3.load(f'roberta_conv_mish_0').model.eval()
        start_logits10, end_logits10 = to_cpu(model10(*xb))
        start_logits10, end_logits10 = start_logits10.float(), end_logits10.float()
        
        model11 = learner3.load(f'roberta_conv_mish_1').model.eval()
        start_logits11, end_logits11 = to_cpu(model11(*xb))
        start_logits11, end_logits11 = start_logits11.float(), end_logits11.float()
        
        model12 = learner3.load(f'roberta_conv_mish_2').model.eval()
        start_logits12, end_logits12 = to_cpu(model12(*xb))
        start_logits12, end_logits12 = start_logits12.float(), end_logits12.float()
        
        model13 = learner3.load(f'roberta_conv_mish_3').model.eval()
        start_logits13, end_logits13 = to_cpu(model13(*xb))
        start_logits13, end_logits13 = start_logits13.float(), end_logits13.float()
        
        model14 = learner3.load(f'roberta_conv_mish_4').model.eval()
        start_logits14, end_logits14 = to_cpu(model14(*xb))
        start_logits14, end_logits14 = start_logits14.float(), end_logits14.float()
        
        input_ids = to_cpu(xb[0])
        offsets = to_cpu(xb[2])
        
        start_logits = (start_logits0 + start_logits1 + start_logits2 + start_logits3 + start_logits4 + start_logits5 + start_logits6 + start_logits7 + start_logits8 + start_logits9 + start_logits10 + start_logits11 + start_logits12 + start_logits13 + start_logits14) / 15
        end_logits = (end_logits0 + end_logits1 + end_logits2 + end_logits3 + end_logits4 + end_logits5 + end_logits6 + end_logits7 + end_logits8 + end_logits9 + end_logits10 + end_logits11 + end_logits12 + end_logits13 + end_logits14) / 15
        
        for i in range(len(input_ids)):
            
            _offsets = offsets[i]
#             start_idx, end_idx = torch.argmax(start_logits[i]), torch.argmax(end_logits[i])

            start_idx, end_idx = get_best_start_end_idxs(start_logits[i], end_logits[i])
            original_start, original_end = _offsets[start_idx][0], _offsets[end_idx][1]
            pred_span = test_ds.df.text[test_df_idx][original_start : original_end]
            preds.append(pred_span)
            test_df_idx += 1
# Out:
# 100%|██████████| 28/28 [12:20<00:00, 26.45s/it]

# %%
a = pd.DataFrame(preds)

# %%
for fold in range(5):
    learner = Learner(data, model, loss_func = loss_fn(), path = path/'models', model_dir=f".")
    model0 = learner.load(f'roberta_conv_news_fold_{fold}').model.eval()
    learner.save(f'roberta_conv_jel_loss_{fold}',with_opt=False)

# %%
# learner = Learner(data, model, loss_func = loss_fn(), path = path/'models/electra', model_dir=f".")
# learner.load(f'electra-qa-fold_4').save(f'electra_fold_es_4', with_opt=False)

# %%
out_df = test_df

# %%
out_df['selected_text'] = preds
#trying to predict neural
out_df['selected_text'] = out_df.apply(lambda o: o['text'] if len(o['text']) < 3 else o['selected_text'], 1)
# out_df['selected_text'] = out_df.apply(lambda o: o['text'] if o['sentiment'] == 'neutral' else o['selected_text'], 1)

# %%
for idx, row in test_df.iterrows():
    if row.sentiment_x == 'neutral' and row.sentiment_y =='neutral':
        if jaccard(row.text, row.selected_text) >=0.7:
            test_df.selected_text[idx] = row.text
            print(idx)
# Out:
# 8
# 12
# 23
# 31
# 43
# 50
# 51
# 54
# 61
# 62
# 67
# 73
# 85
# 88
# 89
# 100
# 104
# 110
# 112
# 122
# 131
# 133
# 155
# 173
# 176
# 185
# 196
# 199
# 201
# 208
# 237
# 270
# 272
# 275
# 300
# 301
# 302
# 313
# 314
# 316
# 318
# 341
# 348
# 350
# 354
# 362
# 367
# 373
# 382
# 387
# 399
# 400
# 420
# 422
# 423
# 429
# 436
# 437
# 442
# 447
# 449
# 458
# 460
# 472
# 477
# 484
# 490
# 491
# 501
# 516
# 518
# 523
# 525
# 527
# 539
# 542
# 550
# 569
# 571
# 574
# 586
# 589
# 605
# 608
# 611
# 614
# 617
# 620
# 639
# 648
# 654
# 664
# 667
# 695
# 696
# 707
# 715
# 719
# 734
# 736
# 739
# 740
# 754
# 756
# 757
# 758
# 773
# 785
# 788
# 789
# 792
# 801
# 812
# 817
# 825
# 828
# 830
# 834
# 835
# 841
# 843
# 857
# 882
# 888
# 894
# 899
# 901
# 912
# 914
# 916
# 920
# 924
# 925
# 932
# 935
# 940
# 941
# 947
# 959
# 968
# 975
# 981
# 982
# 991
# 999
# 1011
# 1018
# 1020
# 1043
# 1044
# 1076
# 1077
# 1098
# 1099
# 1100
# 1107
# 1108
# 1125
# 1126
# 1130
# 1138
# 1142
# 1159
# 1166
# 1167
# 1170
# 1181
# 1189
# 1197
# 1224
# 1225
# 1227
# 1231
# 1238
# 1239
# 1252
# 1269
# 1271
# 1284
# 1288
# 1289
# 1309
# 1310
# 1312
# 1315
# 1327
# 1333
# 1335
# 1342
# 1349
# 1357
# 1366
# 1369
# 1372
# 1380
# 1383
# 1422
# 1428
# 1431
# 1442
# 1448
# 1457
# 1461
# 1467
# 1470
# 1478
# 1481
# 1497
# 1508
# 1509
# 1514
# 1518
# 1521
# 1523
# 1526
# 1527
# 1530
# 1535
# 1550
# 1556
# 1559
# 1560
# 1566
# 1567
# 1571
# 1586
# 1595
# 1598
# 1600
# 1606
# 1614
# 1617
# 1619
# 1622
# 1629
# 1633
# 1649
# 1651
# 1660
# 1664
# 1665
# 1667
# 1672
# 1684
# 1693
# 1735
# 1737
# 1740
# 1753
# 1761
# 1763
# 1764
# 1768
# 1773
# 1779
# 1781
# 1782
# 1785
# 1790
# 1798
# 1813
# 1816
# 1820
# 1835
# 1846
# 1848
# 1852
# 1864
# 1865
# 1866
# 1870
# 1880
# 1881
# 1885
# 1911
# 1925
# 1930
# 1932
# 1938
# 1940
# 1954
# 1966
# 1972
# 1979
# 1982
# 1994
# 2004
# 2027
# 2034
# 2035
# 2042
# 2048
# 2049
# 2052
# 2056
# 2065
# 2067
# 2069
# 2093
# 2099
# 2104
# 2106
# 2114
# 2125
# 2127
# 2142
# 2148
# 2159
# 2163
# 2166
# 2175
# 2176
# 2184
# 2186
# 2188
# 2204
# 2206
# 2208
# 2212
# 2213
# 2218
# 2219
# 2236
# 2246
# 2250
# 2259
# 2261
# 2268
# 2273
# 2280
# 2284
# 2285
# 2306
# 2310
# 2311
# 2316
# 2334
# 2335
# 2342
# 2344
# 2345
# 2350
# 2352
# 2358
# 2359
# 2362
# 2363
# 2366
# 2370
# 2374
# 2378
# 2381
# 2387
# 2396
# 2400
# 2404
# 2418
# 2431
# 2443
# 2449
# 2460
# 2465
# 2468
# 2497
# 2498
# 2506
# 2508
# 2512
# 2526
# 2536
# 2539
# 2540
# 2547
# 2559
# 2563
# 2570
# 2595
# 2596
# 2609
# 2619
# 2664
# 2669
# 2670
# 2672
# 2675
# 2686
# 2687
# 2690
# 2693
# 2694
# 2695
# 2698
# 2699
# 2703
# 2709
# 2713
# 2714
# 2717
# 2721
# 2725
# 2734
# 2746
# 2750
# 2761
# 2777
# 2781
# 2789
# 2813
# 2822
# 2826
# 2828
# 2832
# 2833
# 2847
# 2848
# 2854
# 2855
# 2860
# 2867
# 2872
# 2887
# 2926
# 2934
# 2941
# 2945
# 2955
# 2977
# 2981
# 2997
# 3005
# 3010
# 3016
# 3019
# 3023
# 3041
# 3056
# 3069
# 3079
# 3082
# 3106
# 3107
# 3111
# 3116
# 3119
# 3122
# 3135
# 3145
# 3152
# 3170
# 3181
# 3188
# 3190
# 3212
# 3215
# 3224
# 3243
# 3249
# 3255
# 3256
# 3260
# 3280
# 3286
# 3306
# 3307
# 3309
# 3317
# 3329
# 3330
# 3331
# 3337
# 3341
# 3366
# 3376
# 3381
# 3384
# 3398
# 3410
# 3418
# 3419
# 3425
# 3427
# 3434
# 3441
# 3454
# 3456
# 3458
# 3461
# 3499
# 3510

# %%
out_df = out_df[['textID', 'selected_text']]
out_df.to_csv("submission_testing.csv", index=False)

# %%
# out_df.to_csv('test.csv')

# %%
pd.set_option('display.max_rows', 4000)

# %%
subdf
# Out:
#           textID                                      selected_text
# 0     f87dea47db  Last session of the day  http://twitpic.com/67ezh
# 1     96d74cb729                                           exciting
# 2     eee518ae67                                      such a shame!
# 3     01082688c6                                        happy bday!
# 4     33987a8ee5                                        I like it!!
# 5     726e501993                                     that`s great!!
# 6     261932614e                                              HATES
# 7     afa11da83f                                            blocked
# 8     e64208b4ef   and within a short time of the last clue all ...
# 9     37bcad24ca   What did you get?  My day is alright.. haven`...
# 10    24c92644a4                                  argh total bummer
# 11    43b390b336                          I checked.  We didn`t win
# 12    69d6b5d93e   .. and you`re on twitter! Did the tavern bore...
# 13    5c1e0b61a1                                               sad,
# 14    504e45d9d9  I feel like my phones hole is not a virgin. Th...
# 15    ae93ad52a0  don`t like it and i hate my new timetable, hav...
# 16    9fce30159a                                           Miss you
# 17    00d5195223                                             Cramps
# 18    33f19050cf                                           but nice
# 19    f7718b3c23  I`m going into a spiritual stagnentation, its ...
# 20    9ef44428d0                                             Stupid
# 21    be634ebeb0                                            My dead
# 22    3dcf4f7e13                                               bad.
# 23    f0ef04109b                               about to go to sleep
# 24    8be365118e                                               lame
# 25    c50bdd4567                                      thats so cool
# 26    334954f215  hey peoples, dont you just hate being grounded...
# 27    b783916431              Huh, another ScarePoint coding Sunday
# 28    1fa8e6ad66                      look who I found just for you
# 29    be38b29042          we are sweating it out on a hot humid day
# 30    95701e8ed9   guess that depends on if you want to be on th...
# 31    4dd58ecd2c                resorted to eating Mickey Ds ALONE.
# 32    cf553cccd5  There is a faux gothy chick looking at me, sor...
# 33    55c69c2d52     did he ask for your Twitter ID? Your sun sign?
# 34    9b1a52cc02                                    where`d you go!
# 35    cce5c4744a                                               good
# 36    c7f9d559e2                                              Happy
# 37    3d2478db59  So I really need to put the laptop down & star...
# 38    6d846d7d50                                          I`m sorry
# 39    599f51af6b                                        feels sorry
# 40    87daa62920                                             i beat
# 41    6506dc55ff   I always forget SOMETHING when I travel. I am...
# 42    746d87f93e  Should have left car and walked home! I might ...
# 43    ef7ef8e474  i`m only updating this so that brett`s phone b...
# 44    d3d7b13278            about happy, not breaking down in tears
# 45    ddc07db84e                                  Hope ur havin fun
# 46    67afe60d31  i miss my old phone it worked so good until i ...
# 47    17d18ba9ef                                          wonderful
# 48    ab57d75f20                                    im really sorry
# 49    f0acd25d8e                                          Not happy
# 50    cf3b068b03  Is watching acoustic performances! & In the mo...
# 51    d6c34fa875              I`ll oscillate from one to the other.
# 52    614aed9113                               I`m so very tired...
# 53    dfa577d3c1                                             Thanks
# 54    10dcbe4dfb   you should totally come get me and bring me t...
# 55    a0bfb12773                                     You seem nice,
# 56    71f4a9b495   U so dirrrrrty... Why oh why did I pick the H...
# 57    d33ed264b3  almost got a kitty yesterday...but it didn`t w...
# 58    77f88ea9e2  reality needs to check in. schools over. time ...
# 59    fe1deac869                     was definitely a nice peaceful
# 60    e591a725ef          i still dont know what we would do though
# 61    2dbb28cc29  _xo   dang it, so its not certain ? ? ? are yo...
# 62    a7e4ad250a  Change of plans. I am staying in Brandon.  No ...
# 63    7d87899024                                              suck.
# 64    461b51fa58  at starbucks with my love. eff school. i have ...
# 65    c31d79c440                                              cried
# 66    32ee7ef6c2                                           exciting
# 67    29f805a7d2                 Terminator Salvation... by myself.
# 68    d41fe360e4                                           dumbface
# 69    a04c8c8695   Why do I have to enter my registration detail...
# 70    25e42b2bf2                                         i love you
# 71    5843d17b1d                                             cute..
# 72    474d10ff48   TGIF is right...I think I broke my toe last n...
# 73    38e69da3a1   Oherr it`s soon then, do you have plans? I ha...
# 74    972dc5787d                            very young looking dude
# 75    0ba6aaf9aa                                              wrong
# 76    7a81537034                                            cheated
# 77    311d2b185b                        breaks my achy breaky heart
# 78    1e46d72ec6                                               wish
# 79    390f169584   im a lady and ladies don`t move couches. they...
# 80    58129e4130                                         !   Thanks
# 81    e6c9e5e3ab                                      26th February
# 82    cb5e709de8  Guess what? mom adopted a kitty today (11 mont...
# 83    a14b4ff440  Happy Birthday Snickers!!!! ? I hope you have ...
# 84    5d57a5eda2                                         Thank you!
# 85    1e3561e921   lol man i got 2 1 /2 hrs an iont how i woulda...
# 86    c2ea5cb58b                    Not feeling all that well today
# 87    cde0016d6d                                             hurts,
# 88    5fc411e8d1                        _berland LMAO I know I know
# 89    5ffb19ae8f                   Gnight shar   <(` `<)Vega(>` `)>
# 90    76da985a47                            poking me in the armpit
# 91    3a98aa4762                               Happy Mothers Day!!!
# 92    886545bbab                                          Yes, I am
# 93    2afe118dc3               I can`t call Mitch!  Im from sweden!
# 94    704c53f4cf                                              Happy
# 95    71fa60d9ff  was so excited to eat the wartermelon i bought...
# 96    c238c4dbb7                                     cried so hard!
# 97    dc73e85417  Take antibacterial to school to clean your han...
# 98    af63915fa9  I`m leaving work now. Trying to decide if I re...
# 99    eb2fc4d281                                               hope
# 100   f9382a1f7b  oooh, sunshine! A patch of sunshine! And it wi...
# 101   54670ca807     skype call with billie but my webcam dont work
# 102   3ab338c459                                              great
# 103   c7c7f7f025                                        prohibiting
# 104   1256e6a4d2    lol since I got twitter a little while ago, ...
# 105   990cdeae87                         I want to see David cook!!
# 106   9a55d83c79                                           yeh me 2
# 107   c8307a482d   learning tat the scenic way  din plan to go t...
# 108   0a21b662a4   i don`t want to do anything specific, i just ...
# 109   297f7d9e0f                                i miss braddddddddd
# 110   68901906a4  Toy Story 3 trailer premiered with Up. I need ...
# 111   3112944847                         ughh on the phone with HP!
# 112   8f8334ffa2  And- hand made by Dan & Jenn -sock blockers .....
# 113   322546026e                                                yay
# 114   e6c154f9be                                              sadly
# 115   e96d849b35                                        Tis awesome
# 116   124e30d941                                              happy
# 117   fbb5742bbb  _Adel they didn`t reply yet.. wait till they c...
# 118   e90acf3c42                                       thats rough.
# 119   0b0944285d  might have to go back much earlier than expect...
# 120   a11da2d3bf                                             wishin
# 121   161bfc7c8a                                               good
# 122   4a65010643                riley hacked my twitter!  hahaha :]
# 123   1b460c82f0  Big Sad Face   Bing doesn`t work on iPhone.  I...
# 124   43e91a5488                                        I liked it.
# 125   410dd99aa3  man im so sad school is ending  but then again...
# 126   b3eadfc565                                          hilarious
# 127   480894125b                                               best
# 128   001617fca4  oh my god!!! i cried so much!!! watch this guy...
# 129   52f2f23473  My near daily exercise is starting to show res...
# 130   e7e27b0c91                                           Welcome!
# 131   834dc73c0c  Bout to hit pmark then make one of my final me...
# 132   aeb0e9d730      : you get to go home and i have to go to work
# 133   c672c9da1d                              voted for  on CMT.com
# 134   cbee1946d3                                               nice
# 135   b1999f0951                                            sunburn
# 136   25510fbf89                                               nice
# 137   bcb9426abb                                               wish
# 138   0d29624200  I <3 Rupert Grint......& of the boy, Ive accep...
# 139   3f0f5891ab                                               love
# 140   0b34e66ea3                                              jerk!
# 141   11de8c0456                                      Lost My Phone
# 142   d5712716e9                                              thank
# 143   3f90f95beb                                that`s pretty funny
# 144   c108e09b19  TweetDeck is acting really strange! Hum..........
# 145   7223fdccc2                                BUT I SO WANT TO GO
# 146   f254748cdb                                              Happy
# 147   256453d14f                                I can`t believe it!
# 148   8fd01857a9               is dreaming of the weekend... awake!
# 149   37227c0dbf                                       Oh, **** me.
# 150   20aff2fcb1                         yay but you missed naptime
# 151   ca223af36e                                        Life`s Good
# 152   90977e9614                                               love
# 153   433b1ab9ea                                              comfy
# 154   37771d1bc1            _celeste  finally some sleep in silence
# 155   fa99046452  im just up :-| and its 12:43 :O  im so lazy th...
# 156   14760477ad                              is pretty dang tired.
# 157   da908a6635         i have to poop...   is hogging the shitter
# 158   2053a455e9  YES! Im down to 50% full on my dvr  i was at 9...
# 159   1ea547383b   Happy muthath`s day to all moms!!! I salute you!
# 160   6634c62acf                                    Hahaha! Alright
# 161   c7240790da                          good for you and congrats
# 162   08ede23635                              good to know   thanks
# 163   4e87dcff0e                   what are you? flavor of the day?
# 164   4b0b53bc98  weathers let me down this morning...ugh!...had...
# 165   fd3a622954  Just listened to condre scr and got an invitat...
# 166   e34af4fd97  wow, brings back so many happy memories.  LOVE...
# 167   0e8aa10a4e                                               cute
# 168   29148dc95c                                               love
# 169   56a15cf6ca                                               hate
# 170   b99969c2fb                is ONLiNE  http://plurk.com/p/stjdg
# 171   b0f3142cb4    bundy. in 3 days.!!!! warm weather here i come!
# 172   5ff525b74b           Wondering if i cld make things any worse
# 173   4fd80e66e0  a Dutch marketing agency is asking job applica...
# 174   e77a8f8f2d                               Frustratingly slow!!
# 175   4ea7102112                                 I completely agree
# 176   6a14956779          If we don`t pack, she can`t leave, right?
# 177   7c2fcb712e                    ****  lol....where u headed to?
# 178   cdd172d6a7                                              great
# 179   d2a21b3cb7                                             missed
# 180   799e17e7a7                                               nice
# 181   0a49cdbdf6                                               miss
# 182   4a13c1093d   between the Garlic Pills, the Spider bite bet...
# 183   9407ce6ccc   *sighs* Ah well.  Maybe my second email will ...
# 184   820f19ca44    Missed all your tweets again Joe, **** that ...
# 185   683bb73c09   --that came to my mind. So I said it. And it ...
# 186   0d14593b11                looking forward to body works today
# 187   9ac13b3739                                          messed up
# 188   16ee71e6df                                              Sadly
# 189   f5d47f04f5                                        suffocating
# 190   e131c496a2  Meeting my best friend first thing in the morn...
# 191   bc6d7b4364                                               lost
# 192   c87be630b5   Yup theory is GREAT but the reality is beyond...
# 193   e4ad1684bb                                               glad
# 194   f7835156a5                                              woot!
# 195   03bb148b87  'I don`t like Monday, i wish it were sunday, c...
# 196   b47c430fda                ???    ?????? - http://bit.ly/nAcK2
# 197   0234e16010  Waiting for the last movie to finish then am t...
# 198   be9ed19513                                              Happy
# 199   bf7240df91                       Must head back to the office
# 200   2f883c6eb1                                             dirty.
# 201   a1320a5050  http://twitpic.com/4w67k - Camping at black bu...
# 202   d72a60bee8   are you getting my messages or do you have to...
# 203   bc9ebe0002                                     I hate my life
# 204   64ddc1f8a2                                               sick
# 205   03f6b8d900                                              ****!
# 206   2d475b1b23                         depressed again  HATERS!!!
# 207   87473f5175                                  crying real tears
# 208   7a09871d21  _Brown been holding onto this one for a while ...
# 209   96ec2855e4                                               wish
# 210   45cf9ba329  Back from town and my Mac crashed on me  but i...
# 211   bab68144cd  ARCHIE ANDREWS WHAT WERE YOU THINKING?! veronica?
# 212   fc49e426f5                                               best
# 213   a172818c9e  Best Friend and even though she has been gone ...
# 214   036191bb61  love the music.wishing i could watch the live ...
# 215   3ef85c201c                                             bummer
# 216   ea348ea738   He is the truth! But what about Maxwell? You ...
# 217   fd10f463c9                         The racoons ate our bread!
# 218   e6e02e1be6                                           fabulous
# 219   8112c62d00  _in_a_story Glad I`m not the only one. He`s ou...
# 220   0f89951346                                             stupid
# 221   f3ec0395b0                                 it`s very pleasant
# 222   37ffa83550                                        great book!
# 223   cb8c730261                                          good song
# 224   be33b5cb9a  Again working on the internet shop ... don`t t...
# 225   4fed31099f                                    sucked so much.
# 226   de288eb45b                 what causes the frustration buddy?
# 227   7ab82d9fda                                         THANK YOU!
# 228   9d8a45d308                                         saddenning
# 229   d25c4179f6                                              sorry
# 230   6cd35dd82e                                I do my humble best
# 231   65275b51e2                                    cant take thiss
# 232   9fae9e3145                                         good luck!
# 233   e515132ae4   Thanks...I really do appreciate that. I know ...
# 234   df3c7485ae                                     miss you guys!
# 235   bd8ba2ad7e                                               love
# 236   58be40735c                                    Stoooopid thing
# 237   b5a0a16fd7               Hi Simon, let me know when it`s done
# 238   044f146e5c                                            amazing
# 239   a8e17db0cc         Poor little woman with her smushed in head
# 240   abda0ac082                                  is fixin to clean
# 241   b01506af48  Why do you think people say, 'save the drama f...
# 242   53969f2468                                   hate that place.
# 243   4df63939ef                                             failed
# 244   f43efa3560                            SHE LOOKED SOO PRETTY..
# 245   c89e41fc7c                                      follow me too
# 246   b9ec075666  bought three books!! yipee!!  now who`s with m...
# 247   ca333e378d                                  I`m really bored!
# 248   5a91b175f6                                          goodnight
# 249   ac00adda49                                       Feeling sick
# 250   cf9dc7479a                                              scare
# 251   005e2e60d3                    Now I need to change my monitor
# 252   0b1fad03e9   I know dude, i`m doing re-runs, making Jenny ...
# 253   2c72a5582a   WHAT ABOUT ME ??  I VOTE EVERY DAY FOR YOU !!!!!
# 254   af0778ed50                                               fun.
# 255   1e0416ec46  just rocked home from maccas, and now signing ...
# 256   1e6f72ea44                                             sick..
# 257   cc930f7aa8                      eagerly anticipating twitpics
# 258   9c202174a3                   Lots of tasks to complete today.
# 259   b9a1df7a8a                                                sux
# 260   7b3132d3cc                                            chillen
# 261   5f80970983  yay doctors  now interview then back 2 the doc...
# 262   f008d91039                                   Ahhh memories...
# 263   c223721eed                 I`m siiiiiickkk  I dun feel good!!
# 264   7f8a3308f8                                          nostalgic
# 265   3f7adda0a4                                           Glorious
# 266   6c60cf0bb2                                              sorry
# 267   f77651be05                                      arent working
# 268   aff740a028  lovely friends and family= my b-day wish came ...
# 269   c3f1116734                                 My Life Would Suck
# 270   4b57011c85                                 revising for exams
# 271   cb4266c560                                            laughed
# 272   dcb3bb2912   Hi Jordan i`m gonna all of u...I know ur busy...
# 273   f61b40624e                                              __joy
# 274   b6d2229b03   I`d love to but I think the trek from London ...
# 275   299fda8c5b                                            hey hey
# 276   fbea09d42d                                 isnt the best idea
# 277   1b62e0c672                                       Is miserable
# 278   2452a0aa6a                                         delicious.
# 279   8a821c6d63                                            loooved
# 280   0f93ebfb23                   lol, get watching it again  hehe
# 281   dd655c5aee                                 Hope you did great
# 282   e94ceb6edd                    btw - downloaded iphone 3.0 sdk
# 283   61e8b484df                                    bummerrr for me
# 284   5be41389ce                        Sad though about the racism
# 285   bd0f0ebc57   me? A doctor? *laughs* oh, no, no, no. I was ...
# 286   772ba56ce6                                              GREAT
# 287   390f00c85a                                         weird mood
# 288   4a680661d5                                          congrats!
# 289   e2505e6219                                             thanks
# 290   0d85e6d515                                              peace
# 291   086671fad9   ok. lol. i miss you too. i hope your cramps g...
# 292   9c99cd9396                                        good review
# 293   f35cc8bb35                               it wont let me do it
# 294   5ba64af2fd                               I don`t like soup...
# 295   dbd82ea5bd                                      its hilarious
# 296   8b6c53f38b                                             I love
# 297   e8cb7f18bd                                              Happy
# 298   9ea273deaa                                               lost
# 299   cf0d831059  starting the video editing of the first spanki...
# 300   8f0bafc9dc     In effect, your podcast IS the audio versio...
# 301   0888d7dab7  Sunny synday morning. Nicole is up later than ...
# 302   04d3c2d056  Browsing  find everything about university & i...
# 303   8bbaca6e4b  I have not tweeted for SIXTEEN DAYS! I miss it...
# 304   4a9529e753   visit si fr joemar dito bataan (frm camiguin)...
# 305   8be2d4f69f                                            excited
# 306   d9c10546e6                        Ugh I don`t feel well again
# 307   90be8eaffb           I`ve seen too much cellphone commercials
# 308   8ba332dbbd                   with no right arm to strum with.
# 309   1086c26e82                                    That`s so cool.
# 310   b357b9e7d2                                            Amazing
# 311   0050eebd18                                        very useful
# 312   426cb788e5  Gonna go and see my sister at Mount Sinai .......
# 313   d30d23e543                          it was just the handle tg
# 314   04a204382a                          backe backe... MUFFINS!!!
# 315   2bc1a7126b                                             A good
# 316   a2fb29c072                          lasttt mondayyy of classs
# 317   a2bbae6c4c                                        access fun!
# 318   0ce30035ac  I just walked into work, all the while thinkin...
# 319   b3505b0aa7                                             unfair
# 320   99fcc18a8d                                               Good
# 321   2b6bc6920b                                            kill me
# 322   d40dd3b17b                                   Aww, that`s sad.
# 323   5aa8a5280f   I knooww  & my hot water bottle iss in whanga...
# 324   7dd57c2598                                            jealous
# 325   0142108215                     Thank you so much phaoloo !!!!
# 326   f4aba8da1c                                           thankful
# 327   9cf9045a3c                                                bad
# 328   1962095a32                                       like to hear
# 329   9acf7846ab                                        frustrated,
# 330   e4d58eb70f                         oh my god i am dying here.
# 331   791b4a40af   We do! Its been to long! I think i have next ...
# 332   0c415791d1        Change of plans, working inside bar tonight
# 333   3bd0bff670                                             thanks
# 334   c7f27553b8                                               good
# 335   a717783c80                                               kill
# 336   5a2add1cd8                                    Arghhhhhhhhh...
# 337   5999397144   Undervote is just going on  I`m all overalled up
# 338   54a3eab849                                        nom nom nom
# 339   77b6b38e7e     Looks like its another night at the office lol
# 340   dd6ea8c37a                                              hurts
# 341   af08dd0be5                           Got about 2 hours sleep.
# 342   3cd447856a                                            painful
# 343   d7765a3fd6  Lol..2 people in falcon..and boo one of them b...
# 344   509033a1ff  i really need to earn money... so that i can w...
# 345   b09f14d65a                                               poor
# 346   3160620b36       Mozzer cancelled tonight by the looks of it.
# 347   b2e3ebc647                                               booo
# 348   1f9644b008                        morning tweat tweat twitter
# 349   1fee7a1358               Headed home ... Charlie`s at the vet
# 350   42d3659c3d             i wanna b maliks from taking the stage
# 351   8746563ae3                                              happy
# 352   01fb29c047                                           not fair
# 353   065e4c2dba                                     unfortunately!
# 354   d0380dbe70                      about to go to leeds shopping
# 355   d0c092c3ee                                             Sadly,
# 356   ed92ed183a                                             tired,
# 357   75d0302de7                                               YAY!
# 358   96c5092f80                                                fun
# 359   ddbc8dba62                                               like
# 360   80b61dc4e6  favorite thing.  No high fructose corn syrup.....
# 361   37897b1693                                           Nt fair.
# 362   7a4af13b01                        I have nothing witty to say
# 363   000ceaec55                                            me too.
# 364   97cd2255be                Hi ho  hi ho it`s off to work we go
# 365   bebfd966a0                                             Thanks
# 366   bebcdc05ad             u welcome babe, kill the show! Yuuupp!
# 367   e2ea1af68e                                       Hey, Candis.
# 368   25c3c99b1a              I was never a good stereotypical teen
# 369   ee27c73f40  I love my Maitu. N she loves me. Happy mothers...
# 370   f90a6f5da0                                      i am so sorry
# 371   49e9fe8b96  i want to go to singapore but my mother seems not
# 372   b34a3e3d72  JB on the front of factor x!!!!! wooh contest ...
# 373   0a96d05fdf                 so u aren`t going to be in Chicago
# 374   ab3f55a84d                                 love it too much..
# 375   0437867c21                                          So tired.
# 376   80ea9ba96f                                             lovely
# 377   4914c3c579                                      Yay! have fun
# 378   33bb4fcc72                                   Why thank you...
# 379   f0da745521                              lucky! that`s awesome
# 380   351d279fba  Oh god, a moth was living in a **** power outlet!
# 381   b5237966b8  I am craving Burrito Boys - Large halibut, wit...
# 382   55cec41587                          Oh is that time for real?
# 383   2cbc372326  So now we`ll pay more in sales tax...great.  E...
# 384   8997a62a75                                  I love  very much
# 385   bce5834e03                                             misses
# 386   a9b9f7a878                                            awesome
# 387   d72edc0bb2  No TV and no internet make Catherine something...
# 388   2fdd2501d1             Anyone have some advice??? I need it!!
# 389   5fcaa99ec8           Of course there are none left in my size
# 390   3dfd82c60f                                           dreading
# 391   16f31448e1  so now that I have a whole 20 followers, 5 of ...
# 392   bab04dc463                                             haappy
# 393   109b636fa5    I thought  was against licensing stores bc i...
# 394   cc29d748cb  _a_michael It doesn`t look like you`re tired i...
# 395   bf4b4c0f0b       so I slept in a little...well a lot. whooops
# 396   64b297c15e                                               cute
# 397   bc1fbaf4a1   Good night, Rob. Sleep well. Safe travels tom...
# 398   f59d8d766f                                              suck.
# 399   8a1bf14c15   Well I will be making beds, creating noise & ...
# 400   acfcaea70b    Bit of New Scientist, this weeks an last wee...
# 401   97e53162ff                                  dear oh dear.....
# 402   c0b7788e74                         my monday running so fast!
# 403   15c531b290                                               lame
# 404   23efa13d7c                                              happy
# 405   c44b286776  _Cal Work or...(hehe mind in the gutter)! I`m ...
# 406   29ed43caca                                               good
# 407   6693f9c143   you`re surrounded by them! I have no official...
# 408   94e0c7c638                                              great
# 409   6114b48cb9                                it likes to be dumb
# 410   32463a2751                                         overrated.
# 411   65ed990460                                               love
# 412   505f50a90d   I really don`t think I could cope if a baby died
# 413   481e268403                       I am definitely going to try
# 414   5ce968f9be                                       Nice!!!!!!!!
# 415   52ad93b3fe                                           miss her
# 416   e892068fd3               lol that just totally made me laugh,
# 417   226adfd977                                                fun
# 418   47f11efc72   this creepy guy when I was walking the dog  I...
# 419   d7b1ac80c4                                      Good morning!
# 420   401cc22f49                                     is on facebook
# 421   583bae2083  I get to drive my dad to the airport so he can...
# 422   f003be5308  Franco made breakfast for Mom. Here he`s tryin...
# 423   49ce2570e5   http://twitpic.com/4w9h2 better in person had...
# 424   0693a85163                                          be boring
# 425   4b273cd32a   Thank you! You should know that I am both hap...
# 426   22003c0e96  _merchant I agree, but teenage daughter will b...
# 427   0fe049b7ea  Someone out there will soon  be the lucky reci...
# 428   3d1184dabd                                               Good
# 429   c2392d49e0   one of our governors is one of the directors ...
# 430   a25ccabf06                   no internet for a week or longer
# 431   9b3fcf1668                                            Too hot
# 432   d7746b6b68  Is listening to P!nk tunage and trying to teac...
# 433   86c20cf6ee                                     I sure she can
# 434   393b22b6c0  Getting ready for work and the sun is shining,...
# 435   3c03dc0dd0  this aztec mask is harder then i thought! but ...
# 436   25e2db9995  Listenin to some old school new found glory. H...
# 437   d17a3a37e1  Kelly Kelly pays your bills @ 12:15, Kaden pay...
# 438   58f1b52257                                     i want to gooo
# 439   32489d483d                                           spamming
# 440   00d907ce33                                 Hope she LOVES it!
# 441   a7f2db128a                    Ugh fun concert  screen cracked
# 442   d39e6da95c   if you take backstreet boya and put them in s...
# 443   09fea0f3a7                                             happy,
# 444   31eb8ebd2a                                            cuuuute
# 445   4dda8fd71a                                            Praying
# 446   e4d6a48aa7                                         cancelled.
# 447   d0b52412b8                                     Coco still out
# 448   14acfa72dc                                          My Lovely
# 449   c6d6fbb9a6                 Hello again  How`d ur saturday go?
# 450   797f9cddc0   why aren`t you showing up as a #spymaster in ...
# 451   4c5672e236                                         appreciate
# 452   d35f126ad0                                              great
# 453   efdff6dde7  Got caught in the rain. Sand Monsoon all the w...
# 454   4dd3339756                                             misses
# 455   dd3cd66574  Going to bed after the CAVS game  Don`t judge ...
# 456   e83b4e9bf0                                           jealous.
# 457   7a27c3a84d                                                sad
# 458   19de569235  went twitter crazy! last nigh :p well thats wh...
# 459   66f1863628                                  I want chocolate!
# 460   3690fcb40e  http://twitpic.com/4ja8r - Tell me, how can yo...
# 461   bad6311330                                       going better
# 462   75499e3bd1                                  Fun is being had.
# 463   27d6472b81     $#@! My nose stud fell out and I can`t find it
# 464   80995dff29                             _by_spork we shall see
# 465   ca2d9efd4c                                  Excellent analogy
# 466   12bb670169                                               Good
# 467   70b4033f03                          lmao, im only joking mate
# 468   8df42cd45a                                    LUV YA GOODNITE
# 469   82bc030c0d  been busy at work, now must run before traffic...
# 470   9d6473d14d                                                rad
# 471   146257b271                                            awesome
# 472   2fbae49319  #f1 in a few hours guess who is sleepin in the...
# 473   b56108fc36                                      good lookin..
# 474   ed54440a2e  http://twitpic.com/664oz - this is what happen...
# 475   c135b2cef2                               Couldn`t be happier,
# 476   48c3502151                                             Argh..
# 477   5e6040afd3                            Speaking,,,Speaking ...
# 478   3ea60172a0  Paid all my bills only to go out to the mailbo...
# 479   96e1deb162   I could, but that would require today not to ...
# 480   819626535b                                               Glad
# 481   fec3cae0c2  found a swing set for sale 2 blocks from home,...
# 482   89d9167173                                                sad
# 483   dd911923ea                                               pity
# 484   4f8c391159          I`ve got cups but you gotta come get them
# 485   403847cf44                                        Robbie won!
# 486   dad1d09bfb                                          loves you
# 487   56f5217a16                              happy birthday ness!!
# 488   4a9ef1f9d8    Wow, I really hope it gets better. Asthma sucks
# 489   5a42a51462                      feels ..my cousin is a monkey
# 490   c5a584d398  charlie and the chocolate factory, in the mood...
# 491   fee936fdc3   wasn`t the 'layers' just absolute positioned ...
# 492   2813c4cf7e                                               hate
# 493   2246ed3d84                                              Loves
# 494   1b1243d0b5                                          hopefully
# 495   09042bf466                                    Very much true!
# 496   40e3087f9c                        Wish I was still sleeeeping
# 497   ad94e8b662             Have not been very twitter friendly...
# 498   fc0b053a31   I can`t belive you only have one episode to g...
# 499   9f2a0b0b2f   you can also watch Family Guy online. www.fan...
# 500   7516f86838                                           Poorpoor
# 501   2492330594  NOT excited for 32 people reservation in the m...
# 502   9aa7d6a58a                                         impressed.
# 503   083e4f782b                                               good
# 504   ba5e02305b                                   im sososo sad...
# 505   9f4bb12e13                              im sick of being sick
# 506   7a01848c2e  _collins I`m not sure I understand how this tw...
# 507   ae285917c7                                          stressful
# 508   5575fdaf3c                                      getting nervy
# 509   af3fbd5681                                                Aww
# 510   db7211afbf                                           worrying
# 511   23602f214f                                   Made a huge mess
# 512   c3459bc0bb                           when will she b finished
# 513   f02eed05d0                                                cry
# 514   ff7126ea72              gawww, why is facebook being so slow?
# 515   567ef8c2ed                                            im cool
# 516   d50a4dc3bf  Bird poo update... Managed to clean it all off...
# 517   d6bd94911e  Also I was conviced to do a happy dance and th...
# 518   23bf2d69d2  I day til NYC!!!! and the journey soon begins!...
# 519   a6623df1a6                                     i feel in love
# 520   34409c9b8a                                          love you!
# 521   6a36ea6690                                  I double dare you
# 522   c5ec3e9e37   I`m not either. We should have went out *snic...
# 523   e74d67a818                            Hey Esmee. How U doing?
# 524   b09824d000                                  MUAHAHAHHAHAHA...
# 525   3af70d3bc2   nope..not drunk..sometimes I think maybe I sh...
# 526   5e5cb6d0a9                                             lovess
# 527   0db9bf3e1f         EpiCentre Wheelock Place - tourists only..
# 528   4de0e1bb73                                            Perfect
# 529   9a6736745f                                               yayy
# 530   8d40f9e62d                                               glad
# 531   727e51734b           we dont got to see any aweomse people !!
# 532   db23b82d03  'Puke In My Mouth' the brilliant response to *...
# 533   e03a74beca  Good morning. haha I just read that the swine ...
# 534   80b171ef7a                                      bummed out...
# 535   d49d1b7de1                                         I am sorry
# 536   4809e143db                                               good
# 537   0edb544179  having the flu, not the swinish-one, but the flu.
# 538   c50f940f43            we`re pretty sure the shirt isn`t there
# 539   9a27ba671e   You should see our floors before you make tha...
# 540   27c4e1f089                      I am sending healthy, healing
# 541   9965c5a810                                         Good night
# 542   4f6d52cbd8  Prayers for my family and my dog - Mozart is b...
# 543   6c0bac4f19                                          Surprised
# 544   e692bbaf63                   Hope you have a good,safe flight
# 545   365974d586                                              scary
# 546   32db5fc0a5                                              happy
# 547   600c58d8b3                                               LOL.
# 548   792c269f24   i think u have more than enough friends now, ...
# 549   2c6f1f637b  Zs.Nagy presents  http://www.nordugrid.org/man...
# 550   c6322a85c2     _Layne  hmm.. what`s ur fav movie?? tv shows??
# 551   3aa450d12d                                       your amazing
# 552   10ad2966fa                                         Thankfully
# 553   96b3a98962                                       Don`t worry,
# 554   b5c13364bb                                              Sorry
# 555   06ae0360a2  _Walker21 sadly no, I`ll be going to the killu...
# 556   060db97af7   Morning Lou, I Have some housework to do then...
# 557   67d5b57919                                    Extremely happy
# 558   a4388148b8                   hahaha n I`m a do the same for u
# 559   e43b9a1497         I love my mom! Happy Mother`s Day, mommies
# 560   527b27665d            ABSOULUTELY INCREDIBLE! =D i love them!
# 561   dbe35b6a0d                   I never get to do anything cool!
# 562   92c4eadecf  Just got in a fight and kicked out of the bar....
# 563   b1cec36547                             she deserves the best!
# 564   1b5dea3fe9  Early bird gets the worm.  And in my case, bir...
# 565   8d8c915ea5                                           _eat_out
# 566   9b46f1ae17                                            Thanks,
# 567   1c68a5f609                                             thanks
# 568   b9a6b682b2                                              sorry
# 569   092c10bd84  Wow, the new Google icons suck   http://bit.ly...
# 570   84fd3611d6                                              best!
# 571   9b8052833a               tell his people to contact my people
# 572   f9bdd41842                                   KILL IT JASMINE!
# 573   13c47e9bc8                                            awesome
# 574   9a1eaacda3  You`re never alone Just when you think no one ...
# 575   8645bcae50                                        sweet tooth
# 576   b70c6bf768                                       doesn`t work
# 577   f67575d0e9                                  was sad, very sad
# 578   ba93b78cfc                                               good
# 579   77c659aa89                                          goodnight
# 580   303a1773cf   every day of my life lately.    i feel ya gir...
# 581   aa8b44f1b2                        hiya! been looking for you1
# 582   bf95b25f9d                        Aw, that stinks, I`m sorry.
# 583   b21b048c1d  Is trying to recover from a broken heart....ye...
# 584   4f7cba2eff   ach, probably not... they are labeled as MI-5...
# 585   31dbbd2bb4   Ha! Did she find out? The only thing Google c...
# 586   a7506a67a4  _witty  yes france/belgium was good  carnt bel...
# 587   b2c81f2c95                                              slo w
# 588   99c5936498                         you didnt send me the text
# 589   7315faa6ce              oh mannn i`m gonna be there tomorroww
# 590   132462ca21                                      unfortunately
# 591   a7225483b3                                               love
# 592   2dfb1e0fe3                                             I miss
# 593   3a013a37a6                    A little twitter mention on SNL
# 594   b70639aec0                                Poor medicated baby
# 595   0b5a804a3c                                     isn`t working.
# 596   78ccd0cec0                                            enjoyed
# 597   1c464c8953  Me and mum are lost in grangemouth. Utter hila...
# 598   29da8ca76b                    sorry 19/female/atl very lonely
# 599   9d414d77dd                                     Feeling awful,
# 600   4d05d59122                   .. im too obsessed its not fair!
# 601   5a2393940b    I need a bear hug  and Im going to camp today!!
# 602   2fd9eef1f8             I`d send California sunshine your way.
# 603   938c32de3e  I need a present for my mom.  Could anybody he...
# 604   0e3d04ed05  we don`t think southern WV folks like us too m...
# 605   9a0fce6d7e                        learning how to use twitter
# 606   32eb024489  bad mood and i dont feel good. too bad no one ...
# 607   6af90a76e4                                I love you so much.
# 608   2b68738448                                   - Try this one
# 609   af087c9deb                                         , not sure
# 610   8823244442                            butmy eyes won`t let me
# 611   9bb06e4848                      You should check yourz Rayne.
# 612   717e76b467  _66 I haven`t had slip-ons in years, since my ...
# 613   3b6fdcc518                                          expensive
# 614   f6cb27e38e                  He will be here in less than hour
# 615   419f3e9ef8                                            boring.
# 616   f29654c873                                         wonderful.
# 617   7e46f3f92a   ha. nothing any man does is right on mothers ...
# 618   43ad351369                                              worth
# 619   853ebd7b47   Our raid leader made us run drills to practic...
# 620   ef60a2d1e7   And Clang rocks, so you`re using it, right?  ...
# 621   983088f2b4  Unlike cierra, i look like poop today. Whateva...
# 622   50b353f751                       Hope the weather stays nice.
# 623   c4cad35b0f                                            deleted
# 624   9c44566550                      victory is all mine right now
# 625   32b28d840b                                            Hurray!
# 626   d576839165                                  beautiful and fun
# 627   86f3b2e352  Whole body is sore from moving hundreds of pie...
# 628   ef1eb004ff                                oh you are too kind
# 629   36bc98037c   yeah, so quick! And I`m using the 5mm addi`s ...
# 630   faaf6a6f64   I don`t even look at their fabric unless I ne...
# 631   69789cff46                            Pleeaaasee come out sun
# 632   586a76af3d                                              'good
# 633   dfd9f1800b                                              sorry
# 634   e0090fba83  watching the jobros live chat .. not live thou...
# 635   d9e1b10a4f                                               sad.
# 636   0e5d9cd378                                 Dagger 2 my heart.
# 637   1a82a50aa9                                         still love
# 638   57ee48d640   the honesty`s to much...........  Sorry could...
# 639   e0794d1a3e  oh ok i always wondered how that worked. i onl...
# 640   2baa1924cd  noooooooo...another headache...hopefully not a...
# 641   c3261537c6                                             bored.
# 642   4acd2d7380                                              ghost
# 643   259ab53f07                                                bad
# 644   c180265483  often end up higher than my blog on Google sea...
# 645   1e7956b538                          Going to have dinner. bbs
# 646   c8a9799256   we can all but hope... georgia is still wide ...
# 647   9fdac069e1  no phone  i knew i should`ve charged it last n...
# 648   e27ea173e0                                              quite
# 649   e468a185dc                                            oh yes!
# 650   fe626ba958                                              cried
# 651   995db37ffd                              I love this. So much!
# 652   a539826f28                                         frustrated
# 653   5efc764068   Woo - got a fast mobile broadband connection now
# 654   e133dbdc62                  But I really want a Sporebat pet.
# 655   e74af209c6                                Having a nice time!
# 656   aca7565010             I stupidly feel closer to you somehow!
# 657   cac874449f                                             sorry,
# 658   bff45fe27f                                              great
# 659   60521a571e                                          bad homie
# 660   3b6a25d97c    i'm awake whats for breakfast lulu **** on a...
# 661   bcf13877f7                              Good morning everyone
# 662   c4a8602e0a                                     love this one,
# 663   4e06f98760                   shake shake shake shake shake it
# 664   62aebe35b6                                      Raining again
# 665   0237b6fd87                                 good morning world
# 666   c860b3f840  i hope that everyone has been having a great w...
# 667   cfdb8ea6d8                                         back to br
# 668   935a3c2bf5  Time to put the weapons on the charger for the...
# 669   c1e33be64e  Using tiffys computer...it feels different fro...
# 670   000b3211af                                              Happy
# 671   ffa3258a83           Are they both still talking to you then?
# 672   10f2498c35  I want Crimson Gem Saga.  I will just go play ...
# 673   35674461fe                                        great movie
# 674   4c086d6a58  will b having my last V tomorow   will have2li...
# 675   d6a8cee69b  I was awoken by loud banging and it continues ...
# 676   8e4553e921                                          Let`s go!
# 677   cbfe82ef26                                 feels really sick.
# 678   9fb92f7504                                          rawesome!
# 679   49ffb6b465                                               ****
# 680   ed0ace22bf                      u don`t have school today????
# 681   dc346c6f1c                                             broken
# 682   178b3ca782                                  stressing me out.
# 683   0e83e0955a   rt i have had few hearts the past few days on...
# 684   6d3596cdb3  love it when my sister brags! but she`s too ti...
# 685   696a2abd8a  never trust someone else`s battery operated po...
# 686   26d169a9e9                                     You`re awesome
# 687   52fd9f56fb                                            amazing
# 688   2f7b589c41                                           like it.
# 689   1620bd719e                      All done. No more internship.
# 690   6e805ea65a  RIP to officer Edwards. May GOD continue to bl...
# 691   08f6036add  Invasion of the Old Ladies has just ended, sti...
# 692   ce4b5fe266                                        soooo ready
# 693   792c97a352                                               best
# 694   384a8c1c53                                           all good
# 695   8c08631422     On the phone to mum  http://tinyurl.com/otdn9u
# 696   daed8640af                                            me tooo
# 697   0c79867978                          died so yeah....  I`m sad
# 698   fe588dce16            then am anticipating the next ten days!
# 699   30b5985a07                                            boring.
# 700   c3e87ee9c0   yeah, when you start reaching your early-mid-20s
# 701   5bbfbb31da                           getting ready to babysit
# 702   41cf23c2d2  Bad migrane and need to go to dancing tonight....
# 703   e027169ec6  This is less awful than I anticipated. Yet, st...
# ...
# 3299  db828c7bda                                       That`s love.
# 3300  08d12b46b2                                               hope
# 3301  b9078fdb88                                               cry.
# 3302  6434edb2a5                                                Sad
# 3303  93c709ddbb                                           pleasure
# 3304  261ead9c14  Decaf isn`t cutting it right now.  ? http://bl...
# 3305  4bd68426ce                                  That sounds good,
# 3306  6ff929e04b                                     _xo Today yeah
# 3307  d26c5024c9  It would be that Dover race that they played o...
# 3308  ae45bdeb6d                         Humidity is NOT my friend!
# 3309  2d0cd25243                     I`m going to Vegas this summer
# 3310  01fdd344f2                                   stupid spammers!
# 3311  f1e14aaf4e                                Kicking like crazy.
# 3312  cbd87d2326                                         Poor Thing
# 3313  dac8af239c             don`t feel like going to work tomorrow
# 3314  213f65851d                                               well
# 3315  41c5bce464                                   thank u sweetie!
# 3316  669a4ee511                                              wins.
# 3317  d8999ff49b  the weather is good mmm what to do today??? sh...
# 3318  eb96d21b64                                     love love love
# 3319  8e2432e61d  finished work @ midday, had kiddie dinner ... ...
# 3320  6d68218d8b  tMeme> My besties. If only  was there.  on Twi...
# 3321  a00d6e8a18  Hmm, had first pizza in ages and feel a bit si...
# 3322  68238c0940                                             stupid
# 3323  0f870b905c                                             hoping
# 3324  afd1917b36        But why do I have to spend it in the office
# 3325  6d3c1d8ff7                                            lovely!
# 3326  6face8f81f               I can`t, I have an exam on wednesday
# 3327  291a81553f                             today was my first day
# 3328  7b2a38faa7  Need to get an adjustment, neck is all out of ...
# 3329  415e492cfb  Omg Cliff Richard songs in my mind? Just why  lol
# 3330  374ab5e6cd   Wolfram`s got a Chinese Room problem: If Chin...
# 3331  18bcba79be  i`ve not had a reply on my topic yet  lolz wel...
# 3332  f529745a98  Woo hoo.  Sun outside might be able to get som...
# 3333  ba6d7433fe                                ****`m transtelecom
# 3334  056c205514                                               good
# 3335  ab65e404fd               Last time we`ll get tacos like this.
# 3336  0815af3970                                      awesomness!!!
# 3337  897dab966b                                where?  U magazine?
# 3338  694a98d42f                                       are gorgeous
# 3339  1b5a4bc443                                    Great! I`m glad
# 3340  92ef69c5ca  Hmmm... he`s so lovely. I wish he was here now...
# 3341  4c2540598c   They lost me at US ending. ;) I, mean, I don`...
# 3342  201c6c35e2                                      good morning!
# 3343  b3c6a71077  stressed over a sortie tomorrow. And like I am...
# 3344  f78d0594ce  Bread in the oven, room cleaned... almost done...
# 3345  11cab5bac2  ...Gotta love that!!!  Have a great & producti...
# 3346  37c1594abc                                         stuck here
# 3347  d0c93e2a81  stuck in anniston, mississippi. because we got...
# 3348  83d9d8ffbe                                          popular!!
# 3349  a9b155d544                      live chat soooon most likely.
# 3350  37681f23e9  eating some breakfast at Panera Bread. boring ...
# 3351  1305139c4a  _kikireestl nooo. you were on my yahoo account...
# 3352  3cdfcc7a2c   It`s not a reg gig yet, but hopefully it will...
# 3353  09554aef59                      About 60 again todayy yayy!!!
# 3354  c25f1544bd                                            ashamed
# 3355  32cde6dbc5                                            ;i miss
# 3356  4e1101e520                                    I don`t like it
# 3357  ed58e3db1d                                       disappointed
# 3358  daba837f14         I didn`t even get a chance to shop @ Aldi!
# 3359  9664d60456                                                fun
# 3360  a29a6f5c41                                              Happy
# 3361  a4d9ee1aac                                          Good mood
# 3362  5729a6ebb9  Hmm I guess where the world is headed 2day.......
# 3363  b93d5198af  kill myself TWICE in the 15 mins I`ve been out...
# 3364  771545d181               Yay my bday bbq tomorrow! Can`t wait
# 3365  65cbb266bf                                       shut me down
# 3366  b93f47d6b0                            i can still read `em...
# 3367  ce7efcdd0d                                              great
# 3368  d18a58850f                                               Wish
# 3369  f48211d914                                         ambivalent
# 3370  38c94c08b8                                        still alive
# 3371  bb16d5ae08   curses upon the ridiculously slow internetz a...
# 3372  817b6da55c  Okay, so the only reason I`m not buying this a...
# 3373  6bb7fa91b2                                           have fun
# 3374  a9b501f7cd                                                fun
# 3375  540fd43bae                                         looks nice
# 3376  9e734c1ed3                     I`ll put your name on the list
# 3377  0145dc9e7c                                               Good
# 3378  bbcf6de580                                          love you.
# 3379  342c394b9e                                 I`m feeling higher
# 3380  fa625455c7                                              bored
# 3381  14c9c24f55   If you had owned an *actual* cellphone, that ...
# 3382  475e19cb22                                             Oh joy
# 3383  e035bf28b6                            1:30am goin to sleeeeep
# 3384  a2a8a42a36                         Report your findings to me
# 3385  42e4df338b                                    Hey!  It`s easy
# 3386  c0a39bf520          Wondering how come mcdonalds take so long
# 3387  645e740cb0                                               sad,
# 3388  2bca22c7f3   Yup, but what they going do??? He`s the Mothe...
# 3389  c0603f62dd                                       were amazing
# 3390  f0c1aa8e72                                             Im mad
# 3391  a24748151f                                              worst
# 3392  4626b8b37a                                               hurt
# 3393  caa591cb69                          and i had our first fight
# 3394  46632450a3                                      Back to work!
# 3395  7505a3b214                                          beautiful
# 3396  8d69c4d8e4                                   you disappointed
# 3397  91c6546f6b  Aarg, looks like I have to go home to Vegas th...
# 3398  d29e6d773c                                    FAWXING CRAYONS
# 3399  e0589e3ebd   I`m so sorry to hear that you`re in the hospi...
# 3400  a4f6100563  a salt pig thing coz she broke her other one! ...
# 3401  d3d8561006                                        i love you!
# 3402  c005d6cfde                           My birthday is now over.
# 3403  bb3ef3c925                                             thanks
# 3404  b5eb308679                    i miss you, N. we all miss you.
# 3405  936cc72c9d                                      i ate so much
# 3406  1af280ac83  i always have 2 do xtra cleaning b4 leaving......
# 3407  8034e259de   i was think of something with a better view, ...
# 3408  d45f55fad0                                                sad
# 3409  a7a4f1809e                                                yay
# 3410  6564a03aa0                       working the graveyard shift!
# 3411  f6df0fdbff  my dad and i totally just rocked out to the of...
# 3412  b8547d3835   Yup  On to Mother`s Day. Any plans for your b...
# 3413  ed036f1d74                                            problem
# 3414  a237d86171                                        R.I.P curls
# 3415  82dd0bcffe                                             pretty
# 3416  89de64f532   can you get catacombs ffrom the cinemas? i tr...
# 3417  e0f51840d2                                            awesome
# 3418  20f387fede                   You are quite welcome Mr. Poole.
# 3419  5d85831fa3  http://xkcd.com/577/ - today`s xkcd  Looking f...
# 3420  9ef3a57e41                                               miss
# 3421  2a20862961   It`s been raining the past few days but it wa...
# 3422  218412b76a  My younger sister flies in next week for a two...
# 3423  1d865c0717  I have the biggest headache ever. My photosens...
# 3424  7b474b659d   What up? Why no tweets. Are you also filming ...
# 3425  73afc6a90d   yeah whatever...in your twisted mind maybe! ;...
# 3426  00e1d9ed60                                             insult
# 3427  7a059ccc2f                                           mine too
# 3428  e4c90cafae                                  better watch out!
# 3429  675d0f99ee  HARD TO FIND A GUY WITH THE SAME PASSION FOR L...
# 3430  82369ff2a2                  URGHHHHHHHHHH your makeing me cry
# 3431  46f859bacf   absolutely tru...the horror of it still washe...
# 3432  d3b70656cd                           my heart goes out to you
# 3433  d6788e5a4f                                       Sounds good.
# 3434  bef904fa13   awww! you like anne curtis too tho rite?? it`...
# 3435  5f72b7df41                                              happy
# 3436  43661e198b  look up our youtube JessAndNicoleMusic, we are...
# 3437  2cc6d6b3e6                                              haha!
# 3438  4ca97418b7                          oh that totally works too
# 3439  be2fadb2bc                                             bored.
# 3440  1c0b70106f                                               bugs
# 3441  4d9a27e25a   don`t you need a server and someone who knows...
# 3442  834651667b                                          , enjoyed
# 3443  688784c5a9                                            excited
# 3444  7d32d4866a                                You are sooo lucky.
# 3445  0cbab4e443  [Sarah Mcglaclan song in background] Please do...
# 3446  d57bd01b7e                                              shame
# 3447  a5912f5b7b  Gday... Do you know if NHibernate has issues w...
# 3448  b0f7ac544d                               (exhausted and sick)
# 3449  73fd2537e6                                               nice
# 3450  20f35978fb                                             wishin
# 3451  9a8cde88ea   I like how the binary code under your name sa...
# 3452  9f48b1d3fa              I can`t get in, I`m in a waiting room
# 3453  79bd7de23f                                               Glad
# 3454  6b3c3e22d5   I didnt save those links! I dont need distrac...
# 3455  b411bd3afb                                              pain!
# 3456  469196b094  can sum1 tells me how 2 vote 4 miley? it seems...
# 3457  7b65a847b6                thanks dear.. wish you the best too
# 3458  cc28178ef0                                     I said hi to u
# 3459  4200e8b73c                                      OMG - Madness
# 3460  77a7b3282b                             i hope she gets better
# 3461  76b40b8c3d                   http://twitpic.com/1aida - snood
# 3462  1b6fe730fd                   but can`t wait to see it again!!
# 3463  2a04e6e839  Managed to find a bottle of Pimm`s! If only we...
# 3464  f944be482a                    Congrats Sarah!!!!! thats awsum
# 3465  d461b50edb                                              bored
# 3466  d8ab713a6a                                         i love it.
# 3467  e838d1f366                   Oh It was marathon ****? mahasha
# 3468  885b8f47f7                                yes sir i sure did.
# 3469  ac3b9688c6                          Very very very very cool.
# 3470  0f93a7a6ff                                               wish
# 3471  9a38abcf54                                           Congrats
# 3472  863e09ee74        have fun!  i am sad to not be with you guys
# 3473  9501aabea3                                               died
# 3474  40ada63a36  Have a huge block of snack chocolate here. Tis...
# 3475  c956722677                                            too hot
# 3476  1c6ce0a7e3                                     Possibly, yes.
# 3477  5648799bc4  _Ellen and she`s 9.5 and a rescue.. bad hips. ...
# 3478  59fd038492                           will play quake3 in 3min
# 3479  0ef8ddf4a1                                 Hope it went well!
# 3480  50ba66785b   go on msn. i need to talk to you about someth...
# 3481  827fa68ce4                                               best
# 3482  a60b818d1d                                          Goodnight
# 3483  316a1d0f4c                                          miss you.
# 3484  1dc7f3d536   What are those barrels made of? Hey pass that...
# 3485  c08d28468b                                             Thanks
# 3486  043c3b53f8      can`t wait to watch the next season of heroes
# 3487  5fc6e71643                   Bored, making a mothers day card
# 3488  27829d97bd                        literally cannot escape it.
# 3489  603a6f30be            I think Max (my cat) may really be gone
# 3490  f13fd6b067  `m working on a logo on photoshop & it didn`t ...
# 3491  6bda8dca4d                                           it sucks
# 3492  b70db9bf31                                               hurt
# 3493  c9980ac0cd                                               fun!
# 3494  8798f0a924           You know who helps me almost everyday?
# 3495  edef93288d                                              sadly
# 3496  9f345b18c5   Totally agree, she wasn`t even as good as the...
# 3497  5f857f8279  wants to listen to musiq soulchild, but it is ...
# 3498  391211cd64                                                fun
# 3499  b01c4cd28a   that`s me right now, all I can do is stare at...
# 3500  3a92bdf00a                                               nice
# 3501  d24ea15375  It was sunny when I entered the sub-basement. ...
# 3502  c3c168bc80  Orange vitamin water 10 is my new addiction  U...
# 3503  189ea0d26f                                 yay thanku! *hugs*
# 3504  fa117106ef                                  ??  I`m so bummed
# 3505  f66bda14c6                                              proud
# 3506  cf3dafabb3                 .. so I can only recover 10 photos
# 3507  242910ff98  Thank you for saying that  Wish you and the ot...
# 3508  60e5c2c335                                              bored
# 3509  72b5155719                                        I can`t go.
# 3510  bbfe533366               In my moms hair salon, dying my hair
# 3511  4cb0ab19ed  Good morning, to all the mommies happy mothers...
# 3512  58e2a00ab8                                    that`s not good
# 3513  0a0e2a4f78                                            Thanks!
# 3514  975554343f                             They are so ridiculous
# 3515  c7be378db2    im riding the highs and lows of moods now......
# 3516  87737f8e62                                             i hate
# 3517  558fe1316b  On a 10min brake. At wrrkk ... its 11:06 and i...
# 3518  a6687519e2  ok outta all 981 of my followers, only about 1...
# 3519  91f8e27d4c                                             thanks
# 3520  9a10e4813f   Where`d the songs go on the site, I want 'Do ...
# 3521  2b31cedc6d                                        my faves!!!
# 3522  db783cf66a                                           chillin`
# 3523  036cd6abb0                                              hurt.
# 3524  e965e50c60  My hair dresser passed away yesterday from bre...
# 3525  b1c36b70a4   I was supposed to go tomorrow tooooo, but hav...
# 3526  4d2de9d1af                                               best
# 3527  0c2e7ab834                                  HAPPY MOTHERS DAY
# 3528  0bb5b4d19c  Friday evening......what to do, what to do.  I...
# 3529  e5f0e6ef4b                                              tired
# 3530  416863ce47                                             Thanks
# 3531  6332da480c                         sinking into depression...
# 3532  df1baec676                                I love your videos!
# 3533  469e15c5a8                                           ang cute
